# %% [markdown]
# # Ejecución de Agente Orquestador + Evaluador

# %%
# Cargar variables de entorno
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# Importar agente Orquestador
from agents.orquestador import run_orchestrator
# Out:
# Store preexistente detectado en: ./rag/store/hr_docs
# Store preexistente detectado en: ./rag/store/ti_docs
# Store preexistente detectado en: ./rag/store/finance_docs

# %%
question = "¿Se ha planeado recortes presupuestarios?"

run_orchestrator(question)
# Out:
# content='¿Se ha planeado recortes presupuestarios?' additional_kwargs={} response_metadata={} id='09c977f1-4449-4781-8158-c150f9999f3a'
# ...
